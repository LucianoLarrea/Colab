# %% [markdown]
# Load Libraries

# %%
# General
import re
import os
import webbrowser
import numpy as np
import pandas as pd
from IPython.display import display, HTML

# %%
# DL
import torch

# %%
# !pip install youtube-search-python
# !pip install youtube-transcript-api
# Out:
# Requirement already satisfied: youtube-search-python in /usr/local/lib/python3.10/dist-packages (1.6.6)
# Requirement already satisfied: httpx>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from youtube-search-python) (0.27.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.14.2->youtube-search-python) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.14.2->youtube-search-python) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.14.2->youtube-search-python) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.14.2->youtube-search-python) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.14.2->youtube-search-python) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.14.2->youtube-search-python) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.14.2->youtube-search-python) (1.2.2)
# Requirement already satisfied: youtube-transcript-api in /usr/local/lib/python3.10/dist-packages (0.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2024.8.30)

# %%
# Youtube
from youtubesearchpython import VideosSearch
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

# %%
# Huggingface
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, AutoModelForSeq2SeqLM
from transformers import DPRQuestionEncoder, DPRContextEncoder, DPRQuestionEncoderTokenizer, DPRContextEncoderTokenizer

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.1)

# %%
# Vector Databases
import faiss

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.9)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.10)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.133)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.13.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.10.9)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.10)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.133)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.3->langchain-community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.3->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.10->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.10->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.10->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.3->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.3->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.2.2)

# %%
# Langchain | Elevenlabs | Langchain Agents
from langchain import LLMChain
from langchain.prompts import PromptTemplate
from langchain.agents import load_tools, initialize_agent, AgentType
from langchain_community.tools.eleven_labs.text2speech import ElevenLabsText2SpeechTool

# %%
# !pip install ollama
# Out:
# Requirement already satisfied: ollama in /usr/local/lib/python3.10/dist-packages (0.3.3)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from ollama) (0.27.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama) (1.2.2)

# %%
# Ollama
import ollama

# %% [markdown]
# # Load Constants

# %%
# Constants (Predefined Inputs)
DESTINATION = "Amsterdam"
PREFERENCES = ["mUSEUMS", "Outdoor Activities"]
MAX_RESULTS = 20 # Number of videos to fetch
MIN_VIEWS = 10000 # Minimum number of views for a video to be considered
LLM = "facebook/bart-large-cnn"
LOCAL_LLM = "llama3"
MAX_TOKENS = 1000

# %% [markdown]
# # Build PipeLine Step by Step

# %% [markdown]
# 1.Search YouTube Videos

# %%
def parse_views(views_str):
  """ Parses the views string from YouTube and converts it to an integer.
  5,909 views -> 5909"""
  # Remove the views part and any commas
  views_str = views_str.lower().replace('views','').replace(',','').strip()
  return int(views_str) # In case of any parsing error


  # Check if the string ends with "K" (thousand)
  # if "K" in views_str:
  #  return int(float(views_str.replace("K", "")) * 1000)

def fetch_youtube_videos(destination, preferences, MIN_VIEWS, max_results=10):
  """
  Fetches relevant YouTube videos based on the destination and user preferences.
  detination (str)
  preferences (list)
  MIN_VIEWS (int)
  max_results (int)
  """
  # Combine preferences into a search query
  preferences_query = " ".join(preferences)
  search_query = f"{destination} travel guide {preferences_query} Netherlands"

  # Initialize VideosSearch
  videos_search = VideosSearch(search_query, limit=max_results)

  # Execute search
  search_results = videos_search.result()

  videos = []
  for video in search_results["result"]:
    views_str = video["viewCount"]["text"]
    views = parse_views(views_str)
    print(f"parseview {views}")

    # Filter out videos with fewer than MIN_VIEWS
    if views >= MIN_VIEWS:
      videos.append(video)
    video_data = {
        'Title': video['title'],
        'Duration': video['duration'],
        'Channel': video['channel']['name'],
        'Views': views, # Store as integer
        'Link': video['link']
    }
    videos.append(video_data)

  return videos

# %%
print("Fetching relevant YouTube videos about traveling in Amsterdam ...\n")
videos = fetch_youtube_videos(DESTINATION, PREFERENCES, MIN_VIEWS, MAX_RESULTS)
print("Done!")
# Out:
# Fetching relevant YouTube videos about traveling in Amsterdam ...
#
# parseview 284072
# parseview 91805
# parseview 6255
# parseview 5421
# parseview 1070435
# parseview 1019464
# parseview 376463
# parseview 4596
# parseview 82
# parseview 5410
# parseview 238771
# parseview 14454
# parseview 18164
# parseview 107137
# parseview 676088
# parseview 2000
# parseview 451
# parseview 62857
# parseview 2536
# Done!

# %%
len(videos)
# Out:
# 30

# %%
videos
# Out:
# [{'type': 'video',
#   'id': '3izVLop9iKg',
#   'title': 'Top 10 Places to Visit in Amsterdam 2024 | Netherlands Travel Guide',
#   'publishedTime': '1 year ago',
#   'duration': '12:01',
#   'viewCount': {'text': '284,072 views', 'short': '284K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/3izVLop9iKg/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC54729-gi5kBpbgzUC9_6yY104zA',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/3izVLop9iKg/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBKrVrHEM1RCELafsC9Rvwtt8CajQ',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/3izVLop9iKg/mqdefault_6s.webp?du=3000&sqp=CKCvoLgG&rs=AOn4CLCuDpH_VJeblSOXKI0RMlOMqCXcAg',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Welcome to the vibrant '},
#    {'text': 'city', 'bold': True},
#    {'text': ' of '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': ', where history, culture, and '},
#    {'text': 'adventure', 'bold': True},
#    {'text': " await you. In this video, we'll take you on a virtual\xa0..."}],
#   'channel': {'name': 'TRIP XTREME',
#    'id': 'UCbgx3Z8-u-QJa9PuKbI6vXQ',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_kH-HyK6PBzpArbdmwy2PL76DIhQHz_kli0OF8M5Z27lrI=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UCbgx3Z8-u-QJa9PuKbI6vXQ'},
#   'accessibility': {'title': 'Top 10 Places to Visit in Amsterdam 2024 | Netherlands Travel Guide by TRIP XTREME 284,072 views 1 year ago 12 minutes, 1 second',
#    'duration': '12 minutes, 1 second'},
#   'link': 'https://www.youtube.com/watch?v=3izVLop9iKg',
#   'shelfTitle': None},
#  {'Title': 'Top 10 Places to Visit in Amsterdam 2024 | Netherlands Travel Guide',
#   'Duration': '12:01',
#   'Channel': 'TRIP XTREME',
#   'Views': 284072,
#   'Link': 'https://www.youtube.com/watch?v=3izVLop9iKg'},
#  {'type': 'video',
#   'id': 'QEAQ8N6SK6w',
#   'title': 'Top 7 Best Things To Do in Amsterdam (2024) | Ultimate Travel Guide',
#   'publishedTime': '7 months ago',
#   'duration': '8:45',
#   'viewCount': {'text': '91,805 views', 'short': '91K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/QEAQ8N6SK6w/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLABdiM6cBPFEn4UpgMSGr27hAZQGw',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/QEAQ8N6SK6w/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCoaLHtNUe_rhpyjc7sd4nB3qqtUg',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/QEAQ8N6SK6w/mqdefault_6s.webp?du=3000&sqp=COyzoLgG&rs=AOn4CLANEhQYwHZ2pJeSx0bpZYQset-3UQ',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Planning to '},
#    {'text': 'Amsterdam travel', 'bold': True},
#    {'text': ' in 2024? In this video, we have discussed the Top 7 Best '},
#    {'text': 'Things to do', 'bold': True},
#    {'text': ' in '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': ' in 2024.'}],
#   'channel': {'name': 'Travel Awaits You',
#    'id': 'UCGNtgmJIT3FYwYFn-3JdLxQ',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/t076wfubpbiTlEs8iwsSHQandbfdtQFxJO4Az2KORAgO_V4EVgIFtoXVVD_mdlyIyAHJMCO1ZhA=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UCGNtgmJIT3FYwYFn-3JdLxQ'},
#   'accessibility': {'title': 'Top 7 Best Things To Do in Amsterdam (2024) | Ultimate Travel Guide by Travel Awaits You 91,805 views 7 months ago 8 minutes, 45 seconds',
#    'duration': '8 minutes, 45 seconds'},
#   'link': 'https://www.youtube.com/watch?v=QEAQ8N6SK6w',
#   'shelfTitle': None},
#  {'Title': 'Top 7 Best Things To Do in Amsterdam (2024) | Ultimate Travel Guide',
#   'Duration': '8:45',
#   'Channel': 'Travel Awaits You',
#   'Views': 91805,
#   'Link': 'https://www.youtube.com/watch?v=QEAQ8N6SK6w'},
#  {'Title': 'Things to do in Amsterdam with kids | Amsterdam Family Travel Guide 2024',
#   'Duration': '6:44',
#   'Channel': 'Family Travel Guide',
#   'Views': 6255,
#   'Link': 'https://www.youtube.com/watch?v=FvN9fZ2ea8w'},
#  {'Title': 'Amsterdam Travel Guide | Exploring the Gems of the Netherlands',
#   'Duration': '8:23',
#   'Channel': 'Mr. Dibbles',
#   'Views': 5421,
#   'Link': 'https://www.youtube.com/watch?v=T9ZD8zMcpSY'},
#  {'type': 'video',
#   'id': 'GRrXVAFh_XU',
#   'title': 'The BEST things to do in Amsterdam 🇳🇱🍻 handpicked by the locals. #Amsterdam #cityguide',
#   'publishedTime': '6 years ago',
#   'duration': '6:17',
#   'viewCount': {'text': '1,070,435 views', 'short': '1M views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/GRrXVAFh_XU/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA-wcL2waaEu8Ez1TxziR9v-p9Huw',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/GRrXVAFh_XU/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBmfUz7B_VPeBfHLAE7RUpG2Haclg',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/GRrXVAFh_XU/mqdefault_6s.webp?du=3000&sqp=CIKpoLgG&rs=AOn4CLC8vrGhHR1RZrf7rBq99udtGyAfDA',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Want to know exactly what to do and where to go in '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': '? Then you MUST watch this video! Discover a different\xa0...'}],
#   'channel': {'name': 'Withlocals',
#    'id': 'UCIWJJT7XFDc_tAuOBNRtVQg',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/OPn_3NeFJkCVUILA_TN9SC-c7F5kIEElNXUm1grJzEa0A_4LZWjMJDtTFcrfznNhSP0Xef3-=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UCIWJJT7XFDc_tAuOBNRtVQg'},
#   'accessibility': {'title': 'The BEST things to do in Amsterdam 🇳🇱🍻 handpicked by the locals. #Amsterdam #cityguide by Withlocals 1,070,435 views 6 years ago 6 minutes, 17 seconds',
#    'duration': '6 minutes, 17 seconds'},
#   'link': 'https://www.youtube.com/watch?v=GRrXVAFh_XU',
#   'shelfTitle': None},
#  {'Title': 'The BEST things to do in Amsterdam 🇳🇱🍻 handpicked by the locals. #Amsterdam #cityguide',
#   'Duration': '6:17',
#   'Channel': 'Withlocals',
#   'Views': 1070435,
#   'Link': 'https://www.youtube.com/watch?v=GRrXVAFh_XU'},
#  {'type': 'video',
#   'id': '4i5KYDePHDU',
#   'title': '10 Amazing Places to Visit in the Netherlands 4K  🇳🇱  | Netherlands Travel Guide',
#   'publishedTime': '3 years ago',
#   'duration': '11:48',
#   'viewCount': {'text': '1,019,464 views', 'short': '1M views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/4i5KYDePHDU/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBoP-3z6ffp6ZiUlpfCIlMikGSigw',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/4i5KYDePHDU/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC-9hcwdBEYqqt10t4eJnaY46tIXA',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/4i5KYDePHDU/mqdefault_6s.webp?du=3000&sqp=CJCBoLgG&rs=AOn4CLBmBQFuw0PloFW-uZGBu_9sEwwS-g',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': '10 Beautiful Places to Visit in the '},
#    {'text': 'Netherlands', 'bold': True},
#    {'text': ' 4k. Some of the best places to visit in the '},
#    {'text': 'Netherlands', 'bold': True},
#    {'text': ' are right here in this '},
#    {'text': 'travel', 'bold': True},
#    {'text': '\xa0...'}],
#   'channel': {'name': 'Lifestyle Hal',
#    'id': 'UChI-cTok8fJePnryAd0mTvQ',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_lw8fvBaeIbYNuXAEWmVOMlxuMBBh6Es9pONrsGE0F_zaw=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UChI-cTok8fJePnryAd0mTvQ'},
#   'accessibility': {'title': '10 Amazing Places to Visit in the Netherlands 4K  🇳🇱  | Netherlands Travel Guide by Lifestyle Hal 1,019,464 views 3 years ago 11 minutes, 48 seconds',
#    'duration': '11 minutes, 48 seconds'},
#   'link': 'https://www.youtube.com/watch?v=4i5KYDePHDU',
#   'shelfTitle': None},
#  {'Title': '10 Amazing Places to Visit in the Netherlands 4K  🇳🇱  | Netherlands Travel Guide',
#   'Duration': '11:48',
#   'Channel': 'Lifestyle Hal',
#   'Views': 1019464,
#   'Link': 'https://www.youtube.com/watch?v=4i5KYDePHDU'},
#  {'type': 'video',
#   'id': 'rRFsyg7VJ9Y',
#   'title': 'Things To Do In Amsterdam: 3 Day Travel Guide',
#   'publishedTime': '11 months ago',
#   'duration': '17:29',
#   'viewCount': {'text': '376,463 views', 'short': '376K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/rRFsyg7VJ9Y/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCrOtbfTIlqaS0orP8g-BlGZJuw-g',
#     'width': 480,
#     'height': 270}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/rRFsyg7VJ9Y/mqdefault_6s.webp?du=3000&sqp=COa2oLgG&rs=AOn4CLC5E_sOrVNmR2knkQqYi6lIAdB6ag',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Amsterdam', 'bold': True},
#    {'text': ' is one of the most popular cities in Europe for travelers to visit, and for good reason. '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': ' has one off the most\xa0...'}],
#   'channel': {'name': 'Domanation Travels',
#    'id': 'UCMAwcc6Jw0T1WCAoGMVC58w',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_naNS6DsTDoramx3A8eZKwDvt48IizEJSzn7gc-2YThmA=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UCMAwcc6Jw0T1WCAoGMVC58w'},
#   'accessibility': {'title': 'Things To Do In Amsterdam: 3 Day Travel Guide by Domanation Travels 376,463 views 11 months ago 17 minutes',
#    'duration': '17 minutes, 29 seconds'},
#   'link': 'https://www.youtube.com/watch?v=rRFsyg7VJ9Y',
#   'shelfTitle': None},
#  {'Title': 'Things To Do In Amsterdam: 3 Day Travel Guide',
#   'Duration': '17:29',
#   'Channel': 'Domanation Travels',
#   'Views': 376463,
#   'Link': 'https://www.youtube.com/watch?v=rRFsyg7VJ9Y'},
#  {'Title': 'The Best Things to do in Amsterdam  | Travel Guide 2023',
#   'Duration': '6:18',
#   'Channel': 'Brash | Travel And Repeat',
#   'Views': 4596,
#   'Link': 'https://www.youtube.com/watch?v=aTZaOvjyx_c'},
#  {'Title': '19 Best Things to do in Amsterdam (Netherlands) | Amsterdam Travel 4K',
#   'Duration': '33:07',
#   'Channel': 'Better Travelled',
#   'Views': 82,
#   'Link': 'https://www.youtube.com/watch?v=yiqHDfUydkw'},
#  {'Title': 'Amsterdam Travel Guide 2023 - Best Places to Visit In Amsterdam Netherlands - Top Attractions',
#   'Duration': '9:32',
#   'Channel': 'Global Guide',
#   'Views': 5410,
#   'Link': 'https://www.youtube.com/watch?v=4JQJ5UrlFwU'},
#  {'type': 'video',
#   'id': 'zFABm07RtXk',
#   'title': 'Visit Amsterdam - Free Things to Do in Amsterdam, The Netherlands',
#   'publishedTime': '7 years ago',
#   'duration': '7:36',
#   'viewCount': {'text': '238,771 views', 'short': '238K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/zFABm07RtXk/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC0stWjJ8hT-lwUaW8wmJd0jJ8u4A',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/zFABm07RtXk/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBLLjiL4sAquYKBRQaba640VUwv6Q',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/zFABm07RtXk/mqdefault_6s.webp?du=3000&sqp=CIGeoLgG&rs=AOn4CLBnGl6VxXdeFliIUMlJ3kEk3-xUQw',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Free '},
#    {'text': 'Things to Do', 'bold': True},
#    {'text': ' in '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': ', The '},
#    {'text': 'Netherlands', 'bold': True},
#    {'text': '. Thinking about visiting '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': ' and the sticker shock of hotels has put your\xa0...'}],
#   'channel': {'name': 'Wolters World',
#    'id': 'UCFr3sz2t3bDp6Cux08B93KQ',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/7PkUeyZwELIYJdyVHmAPKxxZFqdLxq8e8o073UZcaH5HxLad-TWm_1qCBnFWc68TpTH9bB5If7o=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UCFr3sz2t3bDp6Cux08B93KQ'},
#   'accessibility': {'title': 'Visit Amsterdam - Free Things to Do in Amsterdam, The Netherlands by Wolters World 238,771 views 7 years ago 7 minutes, 36 seconds',
#    'duration': '7 minutes, 36 seconds'},
#   'link': 'https://www.youtube.com/watch?v=zFABm07RtXk',
#   'shelfTitle': None},
#  {'Title': 'Visit Amsterdam - Free Things to Do in Amsterdam, The Netherlands',
#   'Duration': '7:36',
#   'Channel': 'Wolters World',
#   'Views': 238771,
#   'Link': 'https://www.youtube.com/watch?v=zFABm07RtXk'},
#  {'type': 'video',
#   'id': 'rZ46S7BLb08',
#   'title': '15 Best Things to do in Amsterdam, Netherlands [4K UHD]',
#   'publishedTime': '2 years ago',
#   'duration': '12:51',
#   'viewCount': {'text': '14,454 views', 'short': '14K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/rZ46S7BLb08/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA3KC3utAuiSFeqc03Y5kWqSrDP0g',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/rZ46S7BLb08/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCYyztlIsHeXH1nSmL6IshEzsDJtw',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/rZ46S7BLb08/mqdefault_6s.webp?du=3000&sqp=CJrMoLgG&rs=AOn4CLDbKsY88yrXYqkb_YfuVoNdL0GYew',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Looking for '},
#    {'text': 'things to do', 'bold': True},
#    {'text': ' in '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': '? In this 4K video, I highlight the top 15 best attractions, '},
#    {'text': 'activities', 'bold': True},
#    {'text': ', and neighborhoods!'}],
#   'channel': {'name': 'ViaTravelers',
#    'id': 'UCkKCjq2FHA69utRG4CRBdHQ',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/iYcnmg62s2W4lfPnvt-ijO8Gt69vqWIA57OhDzPIB3yygQNa_2dlpr0gI6h0teifFz-XI41p=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UCkKCjq2FHA69utRG4CRBdHQ'},
#   'accessibility': {'title': '15 Best Things to do in Amsterdam, Netherlands [4K UHD] by ViaTravelers 14,454 views 2 years ago 12 minutes, 51 seconds',
#    'duration': '12 minutes, 51 seconds'},
#   'link': 'https://www.youtube.com/watch?v=rZ46S7BLb08',
#   'shelfTitle': None},
#  {'Title': '15 Best Things to do in Amsterdam, Netherlands [4K UHD]',
#   'Duration': '12:51',
#   'Channel': 'ViaTravelers',
#   'Views': 14454,
#   'Link': 'https://www.youtube.com/watch?v=rZ46S7BLb08'},
#  {'type': 'video',
#   'id': '7GnWd4U2nEY',
#   'title': 'Amsterdam Travel Guide 2023 | 10 BEST Tips & Things to do',
#   'publishedTime': '1 year ago',
#   'duration': '6:59',
#   'viewCount': {'text': '18,164 views', 'short': '18K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/7GnWd4U2nEY/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAfwymlhj_37YeB_ERqAM3kGFcbLQ',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/7GnWd4U2nEY/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB5iEOzc9HnYKUlPINT2Lyd1iEyig',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/7GnWd4U2nEY/mqdefault_6s.webp?du=3000&sqp=CODHoLgG&rs=AOn4CLCniAq4Zig3fxWDQyklCjp0omvU9Q',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Welcome to this '},
#    {'text': 'Amsterdam Travel Guide', 'bold': True},
#    {'text': " 2023 with 10 of the best tips and to do's. "},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': ', the capital and largest city of the\xa0...'}],
#   'channel': {'name': 'Travelment',
#    'id': 'UCPvQQo3W4buCib3YIPqCtNw',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/raExRi_AaQr-rlqe9X500gwz60f2XtIvlVRaBG9iPmKAMYFJMrBNknDJv_l302FLufNxMnhx3w=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UCPvQQo3W4buCib3YIPqCtNw'},
#   'accessibility': {'title': 'Amsterdam Travel Guide 2023 | 10 BEST Tips & Things to do by Travelment 18,164 views 1 year ago 6 minutes, 59 seconds',
#    'duration': '6 minutes, 59 seconds'},
#   'link': 'https://www.youtube.com/watch?v=7GnWd4U2nEY',
#   'shelfTitle': None},
#  {'Title': 'Amsterdam Travel Guide 2023 | 10 BEST Tips & Things to do',
#   'Duration': '6:59',
#   'Channel': 'Travelment',
#   'Views': 18164,
#   'Link': 'https://www.youtube.com/watch?v=7GnWd4U2nEY'},
#  {'type': 'video',
#   'id': 'wfMDqITQrKI',
#   'title': 'How to Spend 3 Days in AMSTERDAM Netherlands | Travel Itinerary',
#   'publishedTime': '7 months ago',
#   'duration': '20:47',
#   'viewCount': {'text': '107,137 views', 'short': '107K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/wfMDqITQrKI/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBlSs2386NXLi_PLrkmYvD2QJeZVw',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/wfMDqITQrKI/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC4AYDSkm0bmjJFZumyd0IPdnQyjA',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/wfMDqITQrKI/mqdefault_6s.webp?du=3000&sqp=CMCvoLgG&rs=AOn4CLBg9YSYgGlxtKRmkifBVXHcI91UgQ',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Get ready for an unforgettable journey through the vibrant heart of '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': ', '},
#    {'text': 'Netherlands', 'bold': True},
#    {'text': "! We're thrilled to bring you the\xa0..."}],
#   'channel': {'name': 'Exotic Vacation',
#    'id': 'UClDHklFpCTrQ6p6EJFHIl4g',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/6ySOCt5SiOdQnnlmpQHZx6a2gjsxkzoopdKg9713LxCZbzKjZX0HBLeerRPP6RRc4Mw3gjffnuc=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UClDHklFpCTrQ6p6EJFHIl4g'},
#   'accessibility': {'title': 'How to Spend 3 Days in AMSTERDAM Netherlands | Travel Itinerary by Exotic Vacation 107,137 views 7 months ago 20 minutes',
#    'duration': '20 minutes, 47 seconds'},
#   'link': 'https://www.youtube.com/watch?v=wfMDqITQrKI',
#   'shelfTitle': None},
#  {'Title': 'How to Spend 3 Days in AMSTERDAM Netherlands | Travel Itinerary',
#   'Duration': '20:47',
#   'Channel': 'Exotic Vacation',
#   'Views': 107137,
#   'Link': 'https://www.youtube.com/watch?v=wfMDqITQrKI'},
#  {'type': 'video',
#   'id': 'miOJ1fA4nz0',
#   'title': 'TOP 20 Things to Do in AMSTERDAM Netherlands 2024 | Travel Guide',
#   'publishedTime': '3 years ago',
#   'duration': '18:15',
#   'viewCount': {'text': '676,088 views', 'short': '676K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/miOJ1fA4nz0/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDqVYBQjh9i-Yv_xtxk9-krEvIQJQ',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/miOJ1fA4nz0/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDX5CzFn-xqYF3djPz_c5hpcFSJlw',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/miOJ1fA4nz0/mqdefault_6s.webp?du=3000&sqp=CO7EoLgG&rs=AOn4CLBrdMLkdlqzylkgnktIFpFA_dodPg',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'The best '},
#    {'text': 'things to do', 'bold': True},
#    {'text': ' in '},
#    {'text': 'Amsterdam', 'bold': True},
#    {'text': ' in the '},
#    {'text': 'Netherlands', 'bold': True},
#    {'text': ' are not always easy to figure out. Especially during the new normal.'}],
#   'channel': {'name': 'Max Nomad',
#    'id': 'UC7KNnrC4a3Egv09CLSO0ccA',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_nrdIWb1a4Cr7QS3BZN8xoMvlRW57LMRKeOsQ-KzEZO=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UC7KNnrC4a3Egv09CLSO0ccA'},
#   'accessibility': {'title': 'TOP 20 Things to Do in AMSTERDAM Netherlands 2024 | Travel Guide by Max Nomad 676,088 views 3 years ago 18 minutes',
#    'duration': '18 minutes, 15 seconds'},
#   'link': 'https://www.youtube.com/watch?v=miOJ1fA4nz0',
#   'shelfTitle': None},
#  {'Title': 'TOP 20 Things to Do in AMSTERDAM Netherlands 2024 | Travel Guide',
#   'Duration': '18:15',
#   'Channel': 'Max Nomad',
#   'Views': 676088,
#   'Link': 'https://www.youtube.com/watch?v=miOJ1fA4nz0'},
#  {'Title': 'The Best Things to Do in Amsterdam | Amsterdam Travel Guide: Tips to Make the Most of Your Trip',
#   'Duration': '21:02',
#   'Channel': 'Wanderlust Journey',
#   'Views': 2000,
#   'Link': 'https://www.youtube.com/watch?v=sjzPWxQa6-8'},
#  {'Title': 'How to spend 3 days in Amsterdam Netherlands travel itinerary Under €330!  (Maps + Tips + Costs)',
#   'Duration': '13:26',
#   'Channel': 'Travel Guide Planner',
#   'Views': 451,
#   'Link': 'https://www.youtube.com/watch?v=lREzhb8-A84'},
#  {'type': 'video',
#   'id': '_p45WJJtv7Q',
#   'title': 'Best Places to Visit In Amsterdam - Travel Video',
#   'publishedTime': '1 year ago',
#   'duration': '8:41',
#   'viewCount': {'text': '62,857 views', 'short': '62K views'},
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/_p45WJJtv7Q/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDEFFQjCTY46a0gUqSzJdvwcDptIA',
#     'width': 360,
#     'height': 202},
#    {'url': 'https://i.ytimg.com/vi/_p45WJJtv7Q/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBpMLmoVpYmTfJCBvs8oTkAQJXwxw',
#     'width': 720,
#     'height': 404}],
#   'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/_p45WJJtv7Q/mqdefault_6s.webp?du=3000&sqp=CNyioLgG&rs=AOn4CLDTfYJZ3nzWz9eYDlPAV7RYYszkYA',
#    'width': 320,
#    'height': 180},
#   'descriptionSnippet': [{'text': 'Amsterdam', 'bold': True},
#    {'text': ', the capital '},
#    {'text': 'city', 'bold': True},
#    {'text': ' of the '},
#    {'text': 'Netherlands', 'bold': True},
#    {'text': ', is a vibrant and culturally rich metropolis known for its picturesque canals, historic\xa0...'}],
#   'channel': {'name': 'Travelspot',
#    'id': 'UCHimPuWxxAN-y8sa7oh2qlg',
#    'thumbnails': [{'url': 'https://yt3.ggpht.com/ifIWey-SMzYoF4f1ovCf4YWybgrx4MvqLlA7JLhSgIUyPZYq9uZ5CcPCRxANzHsbkTVhx1BTncg=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'link': 'https://www.youtube.com/channel/UCHimPuWxxAN-y8sa7oh2qlg'},
#   'accessibility': {'title': 'Best Places to Visit In Amsterdam - Travel Video by Travelspot 62,857 views 1 year ago 8 minutes, 41 seconds',
#    'duration': '8 minutes, 41 seconds'},
#   'link': 'https://www.youtube.com/watch?v=_p45WJJtv7Q',
#   'shelfTitle': None},
#  {'Title': 'Best Places to Visit In Amsterdam - Travel Video',
#   'Duration': '8:41',
#   'Channel': 'Travelspot',
#   'Views': 62857,
#   'Link': 'https://www.youtube.com/watch?v=_p45WJJtv7Q'},
#  {'Title': 'The Ultimate Amsterdam Travel Guide: Things to Do in Amsterdam',
#   'Duration': '12:43',
#   'Channel': 'VoyagerVibe',
#   'Views': 2536,
#   'Link': 'https://www.youtube.com/watch?v=ixZBMmH7v0w'}]

# %%
videos_df = pd.DataFrame(videos)
print(videos_df)
# Out:
#      type           id                                              title  \
# 0   video  3izVLop9iKg  Top 10 Places to Visit in Amsterdam 2024 | Net...
# 1     NaN          NaN                                                NaN
# 2   video  QEAQ8N6SK6w  Top 7 Best Things To Do in Amsterdam (2024) | ...
# 3     NaN          NaN                                                NaN
# 4     NaN          NaN                                                NaN
# 5     NaN          NaN                                                NaN
# 6   video  GRrXVAFh_XU  The BEST things to do in Amsterdam 🇳🇱🍻 handpic...
# 7     NaN          NaN                                                NaN
# 8   video  4i5KYDePHDU  10 Amazing Places to Visit in the Netherlands ...
# 9     NaN          NaN                                                NaN
# 10  video  rRFsyg7VJ9Y      Things To Do In Amsterdam: 3 Day Travel Guide
# 11    NaN          NaN                                                NaN
# 12    NaN          NaN                                                NaN
# 13    NaN          NaN                                                NaN
# 14    NaN          NaN                                                NaN
# 15  video  zFABm07RtXk  Visit Amsterdam - Free Things to Do in Amsterd...
# 16    NaN          NaN                                                NaN
# 17  video  rZ46S7BLb08  15 Best Things to do in Amsterdam, Netherlands...
# 18    NaN          NaN                                                NaN
# 19  video  7GnWd4U2nEY  Amsterdam Travel Guide 2023 | 10 BEST Tips & T...
# 20    NaN          NaN                                                NaN
# 21  video  wfMDqITQrKI  How to Spend 3 Days in AMSTERDAM Netherlands |...
# 22    NaN          NaN                                                NaN
# 23  video  miOJ1fA4nz0  TOP 20 Things to Do in AMSTERDAM Netherlands 2...
# 24    NaN          NaN                                                NaN
# 25    NaN          NaN                                                NaN
# 26    NaN          NaN                                                NaN
# 27  video  _p45WJJtv7Q   Best Places to Visit In Amsterdam - Travel Video
# 28    NaN          NaN                                                NaN
# 29    NaN          NaN                                                NaN
#
#     publishedTime duration                                         viewCount  \
# 0      1 year ago    12:01  {'text': '284,072 views', 'short': '284K views'}
# 1             NaN      NaN                                               NaN
# 2    7 months ago     8:45    {'text': '91,805 views', 'short': '91K views'}
# 3             NaN      NaN                                               NaN
# 4             NaN      NaN                                               NaN
# 5             NaN      NaN                                               NaN
# 6     6 years ago     6:17  {'text': '1,070,435 views', 'short': '1M views'}
# 7             NaN      NaN                                               NaN
# 8     3 years ago    11:48  {'text': '1,019,464 views', 'short': '1M views'}
# 9             NaN      NaN                                               NaN
# 10  11 months ago    17:29  {'text': '376,463 views', 'short': '376K views'}
# 11            NaN      NaN                                               NaN
# 12            NaN      NaN                                               NaN
# 13            NaN      NaN                                               NaN
# 14            NaN      NaN                                               NaN
# 15    7 years ago     7:36  {'text': '238,771 views', 'short': '238K views'}
# 16            NaN      NaN                                               NaN
# 17    2 years ago    12:51    {'text': '14,454 views', 'short': '14K views'}
# 18            NaN      NaN                                               NaN
# 19     1 year ago     6:59    {'text': '18,164 views', 'short': '18K views'}
# 20            NaN      NaN                                               NaN
# 21   7 months ago    20:47  {'text': '107,137 views', 'short': '107K views'}
# 22            NaN      NaN                                               NaN
# 23    3 years ago    18:15  {'text': '676,088 views', 'short': '676K views'}
# 24            NaN      NaN                                               NaN
# 25            NaN      NaN                                               NaN
# 26            NaN      NaN                                               NaN
# 27     1 year ago     8:41    {'text': '62,857 views', 'short': '62K views'}
# 28            NaN      NaN                                               NaN
# 29            NaN      NaN                                               NaN
#
#                                            thumbnails  \
# 0   [{'url': 'https://i.ytimg.com/vi/3izVLop9iKg/h...
# 1                                                 NaN
# 2   [{'url': 'https://i.ytimg.com/vi/QEAQ8N6SK6w/h...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   [{'url': 'https://i.ytimg.com/vi/GRrXVAFh_XU/h...
# 7                                                 NaN
# 8   [{'url': 'https://i.ytimg.com/vi/4i5KYDePHDU/h...
# 9                                                 NaN
# 10  [{'url': 'https://i.ytimg.com/vi/rRFsyg7VJ9Y/h...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  [{'url': 'https://i.ytimg.com/vi/zFABm07RtXk/h...
# 16                                                NaN
# 17  [{'url': 'https://i.ytimg.com/vi/rZ46S7BLb08/h...
# 18                                                NaN
# 19  [{'url': 'https://i.ytimg.com/vi/7GnWd4U2nEY/h...
# 20                                                NaN
# 21  [{'url': 'https://i.ytimg.com/vi/wfMDqITQrKI/h...
# 22                                                NaN
# 23  [{'url': 'https://i.ytimg.com/vi/miOJ1fA4nz0/h...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  [{'url': 'https://i.ytimg.com/vi/_p45WJJtv7Q/h...
# 28                                                NaN
# 29                                                NaN
#
#                                         richThumbnail  \
# 0   {'url': 'https://i.ytimg.com/an_webp/3izVLop9i...
# 1                                                 NaN
# 2   {'url': 'https://i.ytimg.com/an_webp/QEAQ8N6SK...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'url': 'https://i.ytimg.com/an_webp/GRrXVAFh_...
# 7                                                 NaN
# 8   {'url': 'https://i.ytimg.com/an_webp/4i5KYDePH...
# 9                                                 NaN
# 10  {'url': 'https://i.ytimg.com/an_webp/rRFsyg7VJ...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://i.ytimg.com/an_webp/zFABm07Rt...
# 16                                                NaN
# 17  {'url': 'https://i.ytimg.com/an_webp/rZ46S7BLb...
# 18                                                NaN
# 19  {'url': 'https://i.ytimg.com/an_webp/7GnWd4U2n...
# 20                                                NaN
# 21  {'url': 'https://i.ytimg.com/an_webp/wfMDqITQr...
# 22                                                NaN
# 23  {'url': 'https://i.ytimg.com/an_webp/miOJ1fA4n...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  {'url': 'https://i.ytimg.com/an_webp/_p45WJJtv...
# 28                                                NaN
# 29                                                NaN
#
#                                    descriptionSnippet  \
# 0   [{'text': 'Welcome to the vibrant '}, {'text':...
# 1                                                 NaN
# 2   [{'text': 'Planning to '}, {'text': 'Amsterdam...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   [{'text': 'Want to know exactly what to do and...
# 7                                                 NaN
# 8   [{'text': '10 Beautiful Places to Visit in the...
# 9                                                 NaN
# 10  [{'text': 'Amsterdam', 'bold': True}, {'text':...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  [{'text': 'Free '}, {'text': 'Things to Do', '...
# 16                                                NaN
# 17  [{'text': 'Looking for '}, {'text': 'things to...
# 18                                                NaN
# 19  [{'text': 'Welcome to this '}, {'text': 'Amste...
# 20                                                NaN
# 21  [{'text': 'Get ready for an unforgettable jour...
# 22                                                NaN
# 23  [{'text': 'The best '}, {'text': 'things to do...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  [{'text': 'Amsterdam', 'bold': True}, {'text':...
# 28                                                NaN
# 29                                                NaN
#
#                                               channel  \
# 0   {'name': 'TRIP XTREME', 'id': 'UCbgx3Z8-u-QJa9...
# 1                                                 NaN
# 2   {'name': 'Travel Awaits You', 'id': 'UCGNtgmJI...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'name': 'Withlocals', 'id': 'UCIWJJT7XFDc_tAu...
# 7                                                 NaN
# 8   {'name': 'Lifestyle Hal', 'id': 'UChI-cTok8fJe...
# 9                                                 NaN
# 10  {'name': 'Domanation Travels', 'id': 'UCMAwcc6...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'name': 'Wolters World', 'id': 'UCFr3sz2t3bDp...
# 16                                                NaN
# 17  {'name': 'ViaTravelers', 'id': 'UCkKCjq2FHA69u...
# 18                                                NaN
# 19  {'name': 'Travelment', 'id': 'UCPvQQo3W4buCib3...
# 20                                                NaN
# 21  {'name': 'Exotic Vacation', 'id': 'UClDHklFpCT...
# 22                                                NaN
# 23  {'name': 'Max Nomad', 'id': 'UC7KNnrC4a3Egv09C...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  {'name': 'Travelspot', 'id': 'UCHimPuWxxAN-y8s...
# 28                                                NaN
# 29                                                NaN
#
#                                         accessibility  \
# 0   {'title': 'Top 10 Places to Visit in Amsterdam...
# 1                                                 NaN
# 2   {'title': 'Top 7 Best Things To Do in Amsterda...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'title': 'The BEST things to do in Amsterdam ...
# 7                                                 NaN
# 8   {'title': '10 Amazing Places to Visit in the N...
# 9                                                 NaN
# 10  {'title': 'Things To Do In Amsterdam: 3 Day Tr...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'title': 'Visit Amsterdam - Free Things to Do...
# 16                                                NaN
# 17  {'title': '15 Best Things to do in Amsterdam, ...
# 18                                                NaN
# 19  {'title': 'Amsterdam Travel Guide 2023 | 10 BE...
# 20                                                NaN
# 21  {'title': 'How to Spend 3 Days in AMSTERDAM Ne...
# 22                                                NaN
# 23  {'title': 'TOP 20 Things to Do in AMSTERDAM Ne...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  {'title': 'Best Places to Visit In Amsterdam -...
# 28                                                NaN
# 29                                                NaN
#
#                                            link  shelfTitle  \
# 0   https://www.youtube.com/watch?v=3izVLop9iKg         NaN
# 1                                           NaN         NaN
# 2   https://www.youtube.com/watch?v=QEAQ8N6SK6w         NaN
# 3                                           NaN         NaN
# 4                                           NaN         NaN
# 5                                           NaN         NaN
# 6   https://www.youtube.com/watch?v=GRrXVAFh_XU         NaN
# 7                                           NaN         NaN
# 8   https://www.youtube.com/watch?v=4i5KYDePHDU         NaN
# 9                                           NaN         NaN
# 10  https://www.youtube.com/watch?v=rRFsyg7VJ9Y         NaN
# 11                                          NaN         NaN
# 12                                          NaN         NaN
# 13                                          NaN         NaN
# 14                                          NaN         NaN
# 15  https://www.youtube.com/watch?v=zFABm07RtXk         NaN
# 16                                          NaN         NaN
# 17  https://www.youtube.com/watch?v=rZ46S7BLb08         NaN
# 18                                          NaN         NaN
# 19  https://www.youtube.com/watch?v=7GnWd4U2nEY         NaN
# 20                                          NaN         NaN
# 21  https://www.youtube.com/watch?v=wfMDqITQrKI         NaN
# 22                                          NaN         NaN
# 23  https://www.youtube.com/watch?v=miOJ1fA4nz0         NaN
# 24                                          NaN         NaN
# 25                                          NaN         NaN
# 26                                          NaN         NaN
# 27  https://www.youtube.com/watch?v=_p45WJJtv7Q         NaN
# 28                                          NaN         NaN
# 29                                          NaN         NaN
#
#                                                 Title Duration  \
# 0                                                 NaN      NaN
# 1   Top 10 Places to Visit in Amsterdam 2024 | Net...    12:01
# 2                                                 NaN      NaN
# 3   Top 7 Best Things To Do in Amsterdam (2024) | ...     8:45
# 4   Things to do in Amsterdam with kids | Amsterda...     6:44
# 5   Amsterdam Travel Guide | Exploring the Gems of...     8:23
# 6                                                 NaN      NaN
# 7   The BEST things to do in Amsterdam 🇳🇱🍻 handpic...     6:17
# 8                                                 NaN      NaN
# 9   10 Amazing Places to Visit in the Netherlands ...    11:48
# 10                                                NaN      NaN
# 11      Things To Do In Amsterdam: 3 Day Travel Guide    17:29
# 12  The Best Things to do in Amsterdam  | Travel G...     6:18
# 13  19 Best Things to do in Amsterdam (Netherlands...    33:07
# 14  Amsterdam Travel Guide 2023 - Best Places to V...     9:32
# 15                                                NaN      NaN
# 16  Visit Amsterdam - Free Things to Do in Amsterd...     7:36
# 17                                                NaN      NaN
# 18  15 Best Things to do in Amsterdam, Netherlands...    12:51
# 19                                                NaN      NaN
# 20  Amsterdam Travel Guide 2023 | 10 BEST Tips & T...     6:59
# 21                                                NaN      NaN
# 22  How to Spend 3 Days in AMSTERDAM Netherlands |...    20:47
# 23                                                NaN      NaN
# 24  TOP 20 Things to Do in AMSTERDAM Netherlands 2...    18:15
# 25  The Best Things to Do in Amsterdam | Amsterdam...    21:02
# 26  How to spend 3 days in Amsterdam Netherlands t...    13:26
# 27                                                NaN      NaN
# 28   Best Places to Visit In Amsterdam - Travel Video     8:41
# 29  The Ultimate Amsterdam Travel Guide: Things to...    12:43
#
#                       Channel      Views  \
# 0                         NaN        NaN
# 1                 TRIP XTREME   284072.0
# 2                         NaN        NaN
# 3           Travel Awaits You    91805.0
# 4         Family Travel Guide     6255.0
# 5                 Mr. Dibbles     5421.0
# 6                         NaN        NaN
# 7                  Withlocals  1070435.0
# 8                         NaN        NaN
# 9               Lifestyle Hal  1019464.0
# 10                        NaN        NaN
# 11         Domanation Travels   376463.0
# 12  Brash | Travel And Repeat     4596.0
# 13           Better Travelled       82.0
# 14               Global Guide     5410.0
# 15                        NaN        NaN
# 16              Wolters World   238771.0
# 17                        NaN        NaN
# 18               ViaTravelers    14454.0
# 19                        NaN        NaN
# 20                 Travelment    18164.0
# 21                        NaN        NaN
# 22            Exotic Vacation   107137.0
# 23                        NaN        NaN
# 24                  Max Nomad   676088.0
# 25         Wanderlust Journey     2000.0
# 26       Travel Guide Planner      451.0
# 27                        NaN        NaN
# 28                 Travelspot    62857.0
# 29                VoyagerVibe     2536.0
#
#                                            Link
# 0                                           NaN
# 1   https://www.youtube.com/watch?v=3izVLop9iKg
# 2                                           NaN
# 3   https://www.youtube.com/watch?v=QEAQ8N6SK6w
# 4   https://www.youtube.com/watch?v=FvN9fZ2ea8w
# 5   https://www.youtube.com/watch?v=T9ZD8zMcpSY
# 6                                           NaN
# 7   https://www.youtube.com/watch?v=GRrXVAFh_XU
# 8                                           NaN
# 9   https://www.youtube.com/watch?v=4i5KYDePHDU
# 10                                          NaN
# 11  https://www.youtube.com/watch?v=rRFsyg7VJ9Y
# 12  https://www.youtube.com/watch?v=aTZaOvjyx_c
# 13  https://www.youtube.com/watch?v=yiqHDfUydkw
# 14  https://www.youtube.com/watch?v=4JQJ5UrlFwU
# 15                                          NaN
# 16  https://www.youtube.com/watch?v=zFABm07RtXk
# 17                                          NaN
# 18  https://www.youtube.com/watch?v=rZ46S7BLb08
# 19                                          NaN
# 20  https://www.youtube.com/watch?v=7GnWd4U2nEY
# 21                                          NaN
# 22  https://www.youtube.com/watch?v=wfMDqITQrKI
# 23                                          NaN
# 24  https://www.youtube.com/watch?v=miOJ1fA4nz0
# 25  https://www.youtube.com/watch?v=sjzPWxQa6-8
# 26  https://www.youtube.com/watch?v=lREzhb8-A84
# 27                                          NaN
# 28  https://www.youtube.com/watch?v=_p45WJJtv7Q
# 29  https://www.youtube.com/watch?v=ixZBMmH7v0w

# %%
print(videos_df[['Title','Duration','Views','Channel']].to_string(index=False))
# Out:
#                                                                                            Title Duration     Views                   Channel
#                                                                                              NaN      NaN       NaN                       NaN
#                              Top 10 Places to Visit in Amsterdam 2024 | Netherlands Travel Guide    12:01  284072.0               TRIP XTREME
#                                                                                              NaN      NaN       NaN                       NaN
#                              Top 7 Best Things To Do in Amsterdam (2024) | Ultimate Travel Guide     8:45   91805.0         Travel Awaits You
#                         Things to do in Amsterdam with kids | Amsterdam Family Travel Guide 2024     6:44    6255.0       Family Travel Guide
#                                   Amsterdam Travel Guide | Exploring the Gems of the Netherlands     8:23    5421.0               Mr. Dibbles
#                                                                                              NaN      NaN       NaN                       NaN
#           The BEST things to do in Amsterdam 🇳🇱🍻 handpicked by the locals. #Amsterdam #cityguide     6:17 1070435.0                Withlocals
#                                                                                              NaN      NaN       NaN                       NaN
#                 10 Amazing Places to Visit in the Netherlands 4K  🇳🇱  | Netherlands Travel Guide    11:48 1019464.0             Lifestyle Hal
#                                                                                              NaN      NaN       NaN                       NaN
#                                                    Things To Do In Amsterdam: 3 Day Travel Guide    17:29  376463.0        Domanation Travels
#                                          The Best Things to do in Amsterdam  | Travel Guide 2023     6:18    4596.0 Brash | Travel And Repeat
#                            19 Best Things to do in Amsterdam (Netherlands) | Amsterdam Travel 4K    33:07      82.0          Better Travelled
#    Amsterdam Travel Guide 2023 - Best Places to Visit In Amsterdam Netherlands - Top Attractions     9:32    5410.0              Global Guide
#                                                                                              NaN      NaN       NaN                       NaN
#                                Visit Amsterdam - Free Things to Do in Amsterdam, The Netherlands     7:36  238771.0             Wolters World
#                                                                                              NaN      NaN       NaN                       NaN
#                                          15 Best Things to do in Amsterdam, Netherlands [4K UHD]    12:51   14454.0              ViaTravelers
#                                                                                              NaN      NaN       NaN                       NaN
#                                        Amsterdam Travel Guide 2023 | 10 BEST Tips & Things to do     6:59   18164.0                Travelment
#                                                                                              NaN      NaN       NaN                       NaN
#                                  How to Spend 3 Days in AMSTERDAM Netherlands | Travel Itinerary    20:47  107137.0           Exotic Vacation
#                                                                                              NaN      NaN       NaN                       NaN
#                                 TOP 20 Things to Do in AMSTERDAM Netherlands 2024 | Travel Guide    18:15  676088.0                 Max Nomad
#  The Best Things to Do in Amsterdam | Amsterdam Travel Guide: Tips to Make the Most of Your Trip    21:02    2000.0        Wanderlust Journey
# How to spend 3 days in Amsterdam Netherlands travel itinerary Under €330!  (Maps + Tips + Costs)    13:26     451.0      Travel Guide Planner
#                                                                                              NaN      NaN       NaN                       NaN
#                                                 Best Places to Visit In Amsterdam - Travel Video     8:41   62857.0                Travelspot
#                                   The Ultimate Amsterdam Travel Guide: Things to Do in Amsterdam    12:43    2536.0               VoyagerVibe

# %%
def display_videos(videos):
  """
  Displays the list of videos in a pandas DataFrame and optionally opens the videos in the browser.
  Parameters:
  videos (list): A list of video dictionaries.
  """

  if not videos:
    print("No videos found with more than 10,000 views.")
    return

  # Create a DataFrame for better display
  videos_df = pd.DataFrame(videos)
  print("\nFetched YouTuv=be videos (Filtered by > 10.000 views):")
  print(videos_df[['Title','Duration','Views','Channel']].to_string(index=False))

  # Optionally, ask the user if they want to open the videos in the browser
  """ open_browser = input("\nDo you want to open the fetched videos in your web? (y/n): ").strip().lower()
  if open_browser == 'y':
    for video in videos:
      webbrowser.open(video['Link'])"""

display_videos(videos)
# Out:
# Fetched YouTuv=be videos (Filtered by > 10.000 views):
#                                                                                            Title Duration     Views                   Channel
#                                                                                              NaN      NaN       NaN                       NaN
#                              Top 10 Places to Visit in Amsterdam 2024 | Netherlands Travel Guide    12:01  284072.0               TRIP XTREME
#                                                                                              NaN      NaN       NaN                       NaN
#                              Top 7 Best Things To Do in Amsterdam (2024) | Ultimate Travel Guide     8:45   91805.0         Travel Awaits You
#                         Things to do in Amsterdam with kids | Amsterdam Family Travel Guide 2024     6:44    6255.0       Family Travel Guide
#                                   Amsterdam Travel Guide | Exploring the Gems of the Netherlands     8:23    5421.0               Mr. Dibbles
#                                                                                              NaN      NaN       NaN                       NaN
#           The BEST things to do in Amsterdam 🇳🇱🍻 handpicked by the locals. #Amsterdam #cityguide     6:17 1070435.0                Withlocals
#                                                                                              NaN      NaN       NaN                       NaN
#                 10 Amazing Places to Visit in the Netherlands 4K  🇳🇱  | Netherlands Travel Guide    11:48 1019464.0             Lifestyle Hal
#                                                                                              NaN      NaN       NaN                       NaN
#                                                    Things To Do In Amsterdam: 3 Day Travel Guide    17:29  376463.0        Domanation Travels
#                                          The Best Things to do in Amsterdam  | Travel Guide 2023     6:18    4596.0 Brash | Travel And Repeat
#                            19 Best Things to do in Amsterdam (Netherlands) | Amsterdam Travel 4K    33:07      82.0          Better Travelled
#    Amsterdam Travel Guide 2023 - Best Places to Visit In Amsterdam Netherlands - Top Attractions     9:32    5410.0              Global Guide
#                                                                                              NaN      NaN       NaN                       NaN
#                                Visit Amsterdam - Free Things to Do in Amsterdam, The Netherlands     7:36  238771.0             Wolters World
#                                                                                              NaN      NaN       NaN                       NaN
#                                          15 Best Things to do in Amsterdam, Netherlands [4K UHD]    12:51   14454.0              ViaTravelers
#                                                                                              NaN      NaN       NaN                       NaN
#                                        Amsterdam Travel Guide 2023 | 10 BEST Tips & Things to do     6:59   18164.0                Travelment
#                                                                                              NaN      NaN       NaN                       NaN
#                                  How to Spend 3 Days in AMSTERDAM Netherlands | Travel Itinerary    20:47  107137.0           Exotic Vacation
#                                                                                              NaN      NaN       NaN                       NaN
#                                 TOP 20 Things to Do in AMSTERDAM Netherlands 2024 | Travel Guide    18:15  676088.0                 Max Nomad
#  The Best Things to Do in Amsterdam | Amsterdam Travel Guide: Tips to Make the Most of Your Trip    21:02    2000.0        Wanderlust Journey
# How to spend 3 days in Amsterdam Netherlands travel itinerary Under €330!  (Maps + Tips + Costs)    13:26     451.0      Travel Guide Planner
#                                                                                              NaN      NaN       NaN                       NaN
#                                                 Best Places to Visit In Amsterdam - Travel Video     8:41   62857.0                Travelspot
#                                   The Ultimate Amsterdam Travel Guide: Things to Do in Amsterdam    12:43    2536.0               VoyagerVibe

# %%
print(videos_df[['Title','Duration','Views','Channel']].to_string(index=False))
# Out:
#                                                                                            Title Duration     Views                   Channel
#                                                                                              NaN      NaN       NaN                       NaN
#                              Top 10 Places to Visit in Amsterdam 2024 | Netherlands Travel Guide    12:01  284072.0               TRIP XTREME
#                                                                                              NaN      NaN       NaN                       NaN
#                              Top 7 Best Things To Do in Amsterdam (2024) | Ultimate Travel Guide     8:45   91805.0         Travel Awaits You
#                         Things to do in Amsterdam with kids | Amsterdam Family Travel Guide 2024     6:44    6255.0       Family Travel Guide
#                                   Amsterdam Travel Guide | Exploring the Gems of the Netherlands     8:23    5421.0               Mr. Dibbles
#                                                                                              NaN      NaN       NaN                       NaN
#           The BEST things to do in Amsterdam 🇳🇱🍻 handpicked by the locals. #Amsterdam #cityguide     6:17 1070435.0                Withlocals
#                                                                                              NaN      NaN       NaN                       NaN
#                 10 Amazing Places to Visit in the Netherlands 4K  🇳🇱  | Netherlands Travel Guide    11:48 1019464.0             Lifestyle Hal
#                                                                                              NaN      NaN       NaN                       NaN
#                                                    Things To Do In Amsterdam: 3 Day Travel Guide    17:29  376463.0        Domanation Travels
#                                          The Best Things to do in Amsterdam  | Travel Guide 2023     6:18    4596.0 Brash | Travel And Repeat
#                            19 Best Things to do in Amsterdam (Netherlands) | Amsterdam Travel 4K    33:07      82.0          Better Travelled
#    Amsterdam Travel Guide 2023 - Best Places to Visit In Amsterdam Netherlands - Top Attractions     9:32    5410.0              Global Guide
#                                                                                              NaN      NaN       NaN                       NaN
#                                Visit Amsterdam - Free Things to Do in Amsterdam, The Netherlands     7:36  238771.0             Wolters World
#                                                                                              NaN      NaN       NaN                       NaN
#                                          15 Best Things to do in Amsterdam, Netherlands [4K UHD]    12:51   14454.0              ViaTravelers
#                                                                                              NaN      NaN       NaN                       NaN
#                                        Amsterdam Travel Guide 2023 | 10 BEST Tips & Things to do     6:59   18164.0                Travelment
#                                                                                              NaN      NaN       NaN                       NaN
#                                  How to Spend 3 Days in AMSTERDAM Netherlands | Travel Itinerary    20:47  107137.0           Exotic Vacation
#                                                                                              NaN      NaN       NaN                       NaN
#                                 TOP 20 Things to Do in AMSTERDAM Netherlands 2024 | Travel Guide    18:15  676088.0                 Max Nomad
#  The Best Things to Do in Amsterdam | Amsterdam Travel Guide: Tips to Make the Most of Your Trip    21:02    2000.0        Wanderlust Journey
# How to spend 3 days in Amsterdam Netherlands travel itinerary Under €330!  (Maps + Tips + Costs)    13:26     451.0      Travel Guide Planner
#                                                                                              NaN      NaN       NaN                       NaN
#                                                 Best Places to Visit In Amsterdam - Travel Video     8:41   62857.0                Travelspot
#                                   The Ultimate Amsterdam Travel Guide: Things to Do in Amsterdam    12:43    2536.0               VoyagerVibe

# %%
# Display clickable links
print("\n### Watch These Videos:")
for idx, video in enumerate(videos, 1):
  # Display as markdown link
  display(HTML(f"{idx}. <a href='{video['link']}' target='_blank'>{idx}. {video['title']}</a>"))
# Out:
# ### Watch These Videos:
# 1. <a href='https://www.youtube.com/watch?v=3izVLop9iKg' target='_blank'>1. Top 10 Places to Visit in Amsterdam 2024 | Netherlands Travel Guide</a>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-47fed00c49b3> in <cell line: 3>()
#       3 for idx, video in enumerate(videos, 1):
#       4   # Display as markdown link
# ----> 5   display(HTML(f"{idx}. <a href='{video['link']}' target='_blank'>{idx}. {video['title']}</a>"))
#
# KeyError: 'link'

# %% [markdown]
# # 2.Transcript YouTube Videos

# %%
def extract_video_id(youtube_url):
  """
  Extracts the video ID from a YouTube URL.
  Parameters:
  youtube_url (str): The URL of the YouTube video.
  Returns:
  str: The video ID if found, otherwise None.
  """
  # Regular expression to extract video ID
  video_id_match = re.search(r'(?:v=|\/)([0-9A-Za-z]{11})', youtube_url)

  if video_id_match:
    return video_id_match.group(1)
  else:
    return None

# %%
# Example
extract_video_id("https://www.youtube.com/watch?v=dQw4w9WgXcQ")
# Output: 'dQw4w9WgXcQ'
# Out:
# 'dQw4w9WgXcQ'

# %%
def extract_transcript(videos_df):
  # Initialize a new column for transcripts
  videos_df['Transcript'] = None

  # Iterate over each video and fetch the transcript
  for index, row in videos_df.iterrows():
    youtube_url = row['Link']
    video_title = row['Title']
    video_id = extract_video_id(youtube_url)

    if video_id:
      try:
        # Fetch the transcript using the video ID
        transcript = YouTubeTranscriptApi.get_transcript(video_id)

        # Combine the transcript segments into a single string
        transcript = ' '.join([segment['text'] for segment in transcript_list])

        # Store the transcript in the DataFrame
        videos_df.at[index, 'Transcript'] = transcript
        print(f"Transcript fetched for '{video_title}'")

      except TranscriptsDisabled:
        print(f"Transcripts are disabled for '{video_title}'")
        videos_df.at[index, 'Transcript'] = "Transcripts are disabled for this video."

      except NoTranscriptFound:
        print(f"No transcript found for '{video_title}'.")
        videos_df.at[index, 'Transcript'] = "No transcript found for this video."

      except Exception as e:
        print(f"An error occurred while fetching the transcript for '{video_title}'. Error: {e}")
        videos_df.at[index, 'Transcript'] = f"An error occurred while fetching the transcript: {e}"

      else:
        print(f"Could not extract video ID from URL: {youtube_url}")
        videos_df.at[index, 'Transcript'] = "Invalid YouTube URL."

    return videos_df
